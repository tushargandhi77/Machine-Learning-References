# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview  vote_average  vote_count
# 0  Imprisoned in the 1940s for the double murder ...         8.704       26119
# 1  Spanning the years 1945 to 1955, a chronicle o...         8.696       19801
# 2  In the continuing saga of the Corleone crime f...         8.577       11958
# 3  The true story of how businessman Oskar Schind...         8.600       15360
# 4  The defense and the prosecution have rested an...         8.543        8231

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# ...

# %%
df.to_csv('movies.csv')
# Out:
# (140, 5)
